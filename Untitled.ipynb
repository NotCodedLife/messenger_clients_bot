# %%
import pandas as pd 
    
# making dataframe 
filepath = "RepGeneral_20221206141603.csv"
df = pd.read_csv(filepath, sep=';', header=None)
# output the dataframe


print(df[2])   # This is the date 
print(df[28])  # This is the name 
print(df[32])  # This is the phone number
print(df[41])  # This is the email
print(df[10])  # Placa
print(df[12])  # Marca
print(df[13])  # Linea
# Out:
# 0      2022-12-01 07:02:36
# 1      2022-12-01 07:04:41
# 2      2022-12-01 07:07:32
# 3      2022-12-01 07:12:40
# 4      2022-12-01 07:24:21
#               ...
# 356    2022-12-06 13:55:17
# 357    2022-12-06 13:59:42
# 358    2022-12-06 14:11:01
# 359    2022-12-06 14:12:07
# 360    2022-12-06 14:16:55
# Name: 2, Length: 361, dtype: object
# 0                   JORGE CETINA SOSA
# 1           CARLOS JULIO PRADA CAMPOS
# 2             LORENA CONSTANZA FIERRO
# 3         JOSE LUIS ARISMENDI SANCHEZ
# 4            RICRADO ASIS MADERA LARA
#                     ...
# 356      MARIA NELLY BARRERA BUITRAGO
# 357    ADRIANA MILENA BETANCUR ACOSTA
# 358           MAQUINAS Y MAQUINAS SAS
# 359          JUAN DAVID BELLO BECERRA
# 360         GUILLERMO LAYTO CASTAÑEDA
# Name: 28, Length: 361, dtype: object
# 0      3.138908e+09
# 1      3.176708e+09
# 2      3.013832e+09
# 3      3.213813e+09
# 4      3.178431e+09
#            ...
# 356    3.138896e+09
# 357    3.114935e+09
# ...

# %%
clients_df = pd.DataFrame()
clients_df['name'] = [i for i in df[28]]
clients_df['date'] = [i for i in df[2]]
clients_df['phone_number'] = [str(i) for i in df[32]]
clients_df['email'] = [i for i in df[41]]
clients_df['car_id'] = [i for i in df[10]]
clients_df['brand'] = [i for i in df[12]]
clients_df['line'] = [i for i in df[13]]
clients_df
# Out:
#                                name                 date  phone_number  \
# 0                 JORGE CETINA SOSA  2022-12-01 07:02:36  3138907806.0
# 1         CARLOS JULIO PRADA CAMPOS  2022-12-01 07:04:41  3176708100.0
# 2           LORENA CONSTANZA FIERRO  2022-12-01 07:07:32  3013832475.0
# 3       JOSE LUIS ARISMENDI SANCHEZ  2022-12-01 07:12:40  3213813347.0
# 4          RICRADO ASIS MADERA LARA  2022-12-01 07:24:21  3178431244.0
# ..                              ...                  ...           ...
# 356    MARIA NELLY BARRERA BUITRAGO  2022-12-06 13:55:17  3138896059.0
# 357  ADRIANA MILENA BETANCUR ACOSTA  2022-12-06 13:59:42  3114935006.0
# 358         MAQUINAS Y MAQUINAS SAS  2022-12-06 14:11:01  3212444584.0
# 359        JUAN DAVID BELLO BECERRA  2022-12-06 14:12:07  3124248710.0
# 360       GUILLERMO LAYTO CASTAÑEDA  2022-12-06 14:16:55  3105555555.0
#
#                           email  car_id    brand                line
# ...

# %%
clients_df.to_csv('testing_a.csv')

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/fw/f_bfxgm51vz4154n0cx55b9m0000gr/T/ipykernel_29406/1650555607.py in <module>
#       1 # importing the module
# ----> 2 import pywhatkit
#       3
#       4 # using Exception Handling to avoid
#       5 # unprecedented errors
#
# ModuleNotFoundError: No module named 'pywhatkit'

# %%
$ pip install pywhatkit
# Out:
#   File "/var/folders/fw/f_bfxgm51vz4154n0cx55b9m0000gr/T/ipykernel_29406/2525596832.py", line 1
#     $ pip install pywhatkit
#     ^
# SyntaxError: invalid syntax

# %%
pip install pywhatkit
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.0/59.0 kB 1.0 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 1.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.7/49.7 kB 1.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 738.7/738.7 kB 6.2 MB/s eta 0:00:0000:0100:01
# ...

# %%
# importing the module
import pywhatkit

# using Exception Handling to avoid
# unprecedented errors
try:

    # sending message to receiver
    # using pywhatkit
    pywhatkit.sendwhatmsg("+573124818111",
                          "Hello from GeeksforGeeks",
                          22, 28)
    print("Successfully Sent!")

except:

    # handling exception
    # and printing error message
    print("An Unexpected Error!")
